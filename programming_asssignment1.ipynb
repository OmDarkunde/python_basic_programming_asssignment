# %% [markdown]
# ## 1. Write a Python program to print &quot;Hello Python&quot;?

# %%
print("Hello python")
# Out:
# Hello python

# %% [markdown]
# ## 2. Write a Python program to do arithmetical operations addition and division.?

# %%
a = float(input("enter a number"))
b = float(input("enter a number"))
c = a+b
d = a/b
print(f"additon = {c} ,  division = {d}")
# Out:
# enter a number10
# enter a number5
# additon = 15.0 ,  division = 2.0

# %% [markdown]
# ## 3. Write a Python program to find the area of a triangle?

# %%
a  = float(input("enter the length of triangle = "))
b = float(input("enter the length of triangle = "))
c = float(input("enter the length of triangle = "))
d = (a+b+c)/2
print(f"area of triangle is  {d}")
# Out:
# enter the length of triangle = 5
# enter the length of triangle = 6
# enter the length of triangle = 9
# area of triangle is  10.0

# %% [markdown]
# ## 4. Write a Python program to swap two variables?

# %%
a = int(input("enter a number ="))
b=  int(input("enter a number ="))
c = a
a = b
b = c

print(a)
print(b)
# Out:
# enter a number =5
# enter a number =6
# 6
# 5

# %% [markdown]
# ## 5. Write a Python program to generate a random number?

# %%
import random 
a = random.randint(0,1000)  
print(a)
# Out:
# 776
